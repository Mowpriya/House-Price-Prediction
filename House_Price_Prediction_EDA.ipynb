# %% [markdown]
# ## House Price Prediction-EDA

# %% [markdown]
# ## Introduction

# %% [raw]
# In the world of buying and selling homes, figuring out the right price is super important. That's where Exploratory Data Analysis (EDA) comes in – it helps us dig into the details of housing data. By looking at stats and cool pictures, we can understand what makes house prices go up or down. This exploration is like a guide, helping people involved in real estate make smart decisions.

# %% [markdown]
# ## Problem Statement

# %% [raw]
# We have a sample data of Real state markets consisting of features like Bedrooms, Area, Bathrooms, Amenities and so on. Based on the data, we need to predict the house price.
# Here in this notebook, we are performing EDA of Housing dataset to analyse the relationship between each features with target feature price and visualizing the realtionship using libraries like Matplotlib and Seaborn

# %% [markdown]
# ## Source of the Dataset

# %% [raw]
# We collected the data from kaggle.com

# %% [markdown]
# ## Size of the Data

# %% [raw]
# Size of the dataset Housing.csv is 30 KB

# %% [markdown]
# ## About the Dataset

# %% [raw]
# This dataset provides key features for predicting house prices, including area, bedrooms, bathrooms, stories, amenities like air conditioning and parking, and information on furnishing status. It enables analysis and modelling to understand the factors impacting house prices and develop accurate predictions in real estate markets.
#
# This dataset contains 13 columns namely area,price,bedrooms,bathrooms,parking,basement,stories,prefarea,airconditioning,hotwaterheating,mainroad,guestroom,furnishingstatus

# %% [markdown]
# ## Libraries Used

# %% [markdown]
# * Numpy
# * Pandas
# * Matplotlib
# * Seaborn

# %% [markdown]
# ## Categories

# %% [raw]
# In this dataset we have both numerical and categorical features

# %% [markdown]
# ## Categorical Columns

# %% [markdown]
# * mainroad
# * guestroom
# * basement
# * hotwaterheating
# * airconditioning
# * prefarea
# * furnishingstatus

# %% [markdown]
# ## Numerical columns

# %% [markdown]
# * price
# * area
# * bedrooms
# * bathrooms
# * stories
# * parking

# %% [markdown]
# ## Overview of the Features

# %% [markdown]
# * This dataset provides comprehensive information for house price prediction, with 13 column names:
#
# * Price: The price of the house.
# * Area: The total area of the house in square feet.
# * Bedrooms: The number of bedrooms in the house.
# * Bathrooms: The number of bathrooms in the house.
# * Stories: The number of stories in the house.
# * Mainroad: Whether the house is connected to the main road (Yes/No).
# * Guestroom: Whether the house has a guest room (Yes/No).
# * Basement: Whether the house has a basement (Yes/No).
# * Hot water heating: Whether the house has a hot water heating system (Yes/No).
# * Airconditioning: Whether the house has an air conditioning system (Yes/No).
# * Parking: The number of parking spaces available within the house.
# * Prefarea: Whether the house is located in a preferred area (Yes/No).
# * Furnishing status: The furnishing status of the house (Fully Furnished, Semi-Furnished, Unfurnished).

# %% [markdown]
# ## Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the dataset using Pandas dataframe

# %%
df= pd.read_csv("Housing.csv")

# %% [markdown]
# ## Checking first 5 rows of the dataset using df.head()

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# ## Checking last 5 rows of the dataset using df.tail()

# %%
df.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %% [markdown]
# ## Checking random 3 samples of the dataset

# %%
df.sample(3)
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 348  3815000  3150         2          2        1       no        no      yes
# 28   8400000  7950         5          2        2      yes        no      yes
# 32   8295000  4880         4          2        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 348              no              no        0       no   semi-furnished
# 28              yes              no        2       no      unfurnished
# 32               no             yes        1      yes        furnished

# %% [markdown]
# ## Overview of the type of data in each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# ## Statistical information of the data

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# ## Shape of the dataset

# %%
df.shape
# Out:
# (545, 13)

# %% [markdown]
# ## Columns of the dataset

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %% [markdown]
# ## Type of data in each column of the dataset

# %%
df.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %% [markdown]
# ## Checking unique values of each column

# %%
for i in df:
    print(i,'\n')
    print(df[i].unique())
    print('===============================')
# Out:
# price
#
# [13300000 12250000 12215000 11410000 10850000 10150000  9870000  9800000
#   9681000  9310000  9240000  9100000  8960000  8890000  8855000  8750000
#   8680000  8645000  8575000  8540000  8463000  8400000  8295000  8190000
#   8120000  8080940  8043000  7980000  7962500  7910000  7875000  7840000
#   7700000  7560000  7525000  7490000  7455000  7420000  7350000  7343000
#   7245000  7210000  7140000  7070000  7035000  7000000  6930000  6895000
#   6860000  6790000  6755000  6720000  6685000  6650000  6629000  6615000
#   6580000  6510000  6475000  6440000  6419000  6405000  6300000  6293000
#   6265000  6230000  6195000  6160000  6125000  6107500  6090000  6083000
#   6020000  5950000  5943000  5880000  5873000  5866000  5810000  5803000
#   5775000  5740000  5652500  5600000  5565000  5530000  5523000  5495000
#   5460000  5425000  5390000  5383000  5320000  5285000  5250000  5243000
#   5229000  5215000  5145000  5110000  5075000  5040000  5033000  5005000
# ...

# %% [markdown]
# ## Checking missing values

# %%
df.isnull().sum()/len(df)*100
# Out:
# price               0.0
# area                0.0
# bedrooms            0.0
# bathrooms           0.0
# stories             0.0
# mainroad            0.0
# guestroom           0.0
# basement            0.0
# hotwaterheating     0.0
# airconditioning     0.0
# parking             0.0
# prefarea            0.0
# furnishingstatus    0.0
# dtype: float64

# %% [markdown]
# ## Checking Duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Separating numerical and categorical columns

# %%
num_col=['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking']
cat_col=['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea', 'furnishingstatus']

# %% [markdown]
# ## Count of each value in categorical columns

# %%
for i in cat_col:
    print(df[i].value_counts())
    print("\n")
# Out:
# mainroad
# yes    468
# no      77
# Name: count, dtype: int64
#
#
# guestroom
# no     448
# yes     97
# Name: count, dtype: int64
#
#
# basement
# no     354
# yes    191
# Name: count, dtype: int64
#
#
# hotwaterheating
# no     520
# yes     25
# Name: count, dtype: int64
#
#
# airconditioning
# no     373
# yes    172
# Name: count, dtype: int64
#
#
# prefarea
# no     417
# yes    128
# Name: count, dtype: int64
#
#
# furnishingstatus
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: count, dtype: int64

# %% [markdown]
# ## Count of each value in numerical column

# %%
for i in num_col:
    print(df[i].value_counts())
    print("\n")
# Out:
# price
# 3500000     17
# 4200000     17
# 4900000     12
# 3150000      9
# 5600000      9
#             ..
# 6580000      1
# 4319000      1
# 4375000      1
# 4382000      1
# 13300000     1
# Name: count, Length: 219, dtype: int64
#
#
# area
# 6000    24
# 3000    14
# 4500    13
# 4000    11
# 5500     9
#         ..
# 6862     1
# 4815     1
# 9166     1
# 6321     1
# 3620     1
# Name: count, Length: 284, dtype: int64
#
#
# bedrooms
# 3    300
# 2    136
# 4     95
# 5     10
# 6      2
# 1      2
# Name: count, dtype: int64
#
#
# bathrooms
# 1    401
# 2    133
# 3     10
# 4      1
# Name: count, dtype: int64
#
#
# stories
# 2    238
# 1    227
# 4     41
# 3     39
# Name: count, dtype: int64
#
#
# parking
# 0    299
# 1    126
# 2    108
# 3     12
# Name: count, dtype: int64

# %% [markdown]
# ## Countplot for all categorical columns in cat_col

# %%
sns.set_style("darkgrid")
sns.set_palette('Set1')
plt.figure(figsize=(15,8))
for i,col in enumerate(cat_col):
    plt.subplot(2,4,i+1)
    sns.countplot(x=col,data=df)

# %% [markdown]
# * Conclusion from above plots
# * There are more number of houses which are connected to mainroad.
# * There are very less number of  houses which has guestroom.
# * There are more houses which do not have basement as compared to number of houses which has a basement
# * There are very less number of houses which ahs hotwaterheating facility.
# * Number of houses which has airconditioning facility is less than houses which do not have airconditioning facility
# * Number of houses that are located in preferred area is less than those which are not in preferred area
# * Count of Semi-furnished houses is largest followed by unfurnished with second highest number and furnished with least number.

# %% [markdown]
# ## Distribution plot of all numerical columns

# %%
sns.set_style("whitegrid")
sns.set_palette('Set2')
plt.figure(figsize=(20,15))
for i,col in enumerate(num_col):
    plt.subplot(2,3,i+1)
    sns.distplot(df[col])

# %% [markdown]
# * From above distribution plots, we can see data is skewed in each of the above features

# %% [markdown]
# ## Pie Chart to view percentage of each category in column "mainroaad"

# %%
df['mainroad'].value_counts(normalize=True).plot(kind='pie',autopct='%0.0f%%')
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# * 86% of houses are connected to main road
# * 14% of the houses are not connected to main road

# %%
v=df['stories'].value_counts(normalize=True)*100
v
# Out:
# stories
# 2    43.669725
# 1    41.651376
# 4     7.522936
# 3     7.155963
# Name: proportion, dtype: float64

# %%
v.plot(kind='barh')
# Out:
# <Axes: ylabel='stories'>

# %% [markdown]
# * From above, we can see that there are 43% houses which are 2 stories
# * 41% houses are 1 stories
# * 7% of the houses are 4 and 5 stories

# %% [markdown]
# ## Checking proportion of houses based on furnishing status

# %%
sns.set_palette('pastel')
df['furnishingstatus'].value_counts(normalize=True).plot(kind='pie',autopct='%0.0f%%')
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# * From above pie plot, we can see 42% houses are semi-furnished
# * 33% houses are unfurnished
# * 26% houses are furnished

# %%
df[num_col].describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df[num_col].mean()
# Out:
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# dtype: float64

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %% [markdown]
# ## Bivariate analysis

# %% [markdown]
# #### Scatter Plot depicting relation between all Categorical columns listed in cat_col and target column Price

# %%
sns.set_style("whitegrid")
sns.set_palette("Set2")
plt.figure(figsize=(20,15))
for i,col in enumerate(cat_col):
    plt.subplot(2,4,i+1)
    sns.swarmplot(x=col,y='price',data=df)

# %% [markdown]
# * From above scatterplots, we can see there are more houses which is near main road compared to houses which is not nearby main road.
# * House price is higher for house which is near mainroad
# * There are higher number of houses which do not have a guestroom,basement and hotwater heating facility.
# * Presence of Guestroom,basement and hotwaterheating facility in a house does not have a significant effect on house price.
# * There are higher number of houses which do not have airconditioning facility, preferred area and semi-furnished.
# * House having airconditioning facility has higher price compared to house which do not airconditioning facility.
# * Furnished houses are more costly than semi-furnished and unfurnished houses.

# %% [markdown]
# ## Stripplot depicting relation between numerical columns and target column price

# %%
num=['area','bedrooms','bathrooms','stories','parking']
sns.set_style("whitegrid")
sns.set_palette("Set1")
plt.figure(figsize=(20,15))
for i,col in enumerate(num):
    plt.subplot(3,2,i+1)
    sns.stripplot(x=col,y='price',data=df)

# %% [markdown]
# * From above plots, we can conclude that:
# * House with large area has higher price as compared to houses with small area.
# * Majority of the houses has 3 bedrooms
# * House price increases with increase in number of bedrooms.
# * House price starts decreasing when number of bedrooms is more than 4.
# * Majority of houses has 1 bathroom
# * Number of bathrooms does not have a significant effect on house price.
# * Number of stories does not affect the house price.
# * House price is higher for houses which has a parking.

# %%
sns.set_style("whitegrid")
sns.set_palette("Set1")
sns.pairplot(data=df,diag_kind='kde',hue='furnishingstatus')

# %%
plt.title("Correlation matrix of numerical columns")
sns.heatmap(df[num_col].corr(),annot=True)
# Out:
# <Axes: title={'center': 'Correlation matrix of numerical columns'}>

# %% [markdown]
# #### Conclusion
# * Correlation between price and area is relatively high- 0.54
# * Correlation between price and bathrooms is next high value-0.52
# * Correlation between price and stories is 0.42
# * Although these corelations are strong enough, we can say price and area are highly co-related as compared to other features

# %% [markdown]
# ## Average price of houses based on area

# %%
d1=df.groupby('area')['price'].mean().reset_index()
d1
# Out:
#       area       price
# 0     1650   3150000.0
# 1     1700   1890000.0
# 2     1836   2275000.0
# 3     1905   4340000.0
# 4     1950   2835000.0
# ..     ...         ...
# 279  12900   4900000.0
# 280  12944   3500000.0
# 281  13200   8365000.0
# 282  15600   5943000.0
# 283  16200  10150000.0
#
# [284 rows x 2 columns]

# %% [markdown]
# ## Plotting the above result using scatterplot

# %%
plt.title("Average price based on Area")
plt.xlabel("Area")
plt.ylabel("Average Price")
sns.scatterplot(x=d1['area'],y=d1['price'])
# Out:
# <Axes: title={'center': 'Average price based on Area'}, xlabel='Area', ylabel='Average Price'>

# %% [markdown]
# * Average price is more when Area is higher.

# %% [markdown]
# ## Average price of House based on number of Bedrooms

# %%
d2=df[['bedrooms','price']].groupby(['bedrooms']).mean().reset_index()
d2
# Out:
#    bedrooms         price
# 0         1  2.712500e+06
# 1         2  3.632022e+06
# 2         3  4.954598e+06
# 3         4  5.729758e+06
# 4         5  5.819800e+06
# 5         6  4.791500e+06

# %% [markdown]
# ## Plotting above result using barplot

# %%
sns.barplot(x='bedrooms',y='price',data=d2)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# * Average price is more for houses with higher number of bedrooms but price starts decreasing after 5 bedrooms.

# %% [markdown]
# ## Relation between columns Bedrooms and Price

# %%
plt.title("Relation between Price and number of Bedrooms")
plt.xlabel('Bedrooms')
plt.ylabel("Price")
sns.boxplot(x='bedrooms',y='price',data=df)
# Out:
# <Axes: title={'center': 'Relation between Price and number of Bedrooms'}, xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# ## Average price of house based on number of bathrooms

# %%
d3=df.groupby('bathrooms')['price'].mean().reset_index()
d3
# Out:
#    bathrooms         price
# 0          1  4.206913e+06
# 1          2  6.209206e+06
# 2          3  7.282100e+06
# 3          4  1.225000e+07

# %% [markdown]
# ## Plotting the above result using bar plot

# %%
plt.title("Average House Price based on Number of Bathrooms")
sns.barplot(x='bathrooms',y='price',data=d3)
# Out:
# <Axes: title={'center': 'Average House Price based on Number of Bathrooms'}, xlabel='bathrooms', ylabel='price'>

# %% [markdown]
# * From above result and plot, we can conclude that higher the number of bathrooms, higher is the price

# %% [markdown]
# ## Average house price based on number of Stories

# %%
d4=df.groupby('stories')['price'].mean().reset_index()
d4
# Out:
#    stories         price
# 0        1  4.170659e+06
# 1        2  4.764074e+06
# 2        3  5.685436e+06
# 3        4  7.208450e+06

# %%
sns.barplot(x='stories',y='price',data=d4)
# Out:
# <Axes: xlabel='stories', ylabel='price'>

# %% [markdown]
# * With increase in number of stories increases the price of the house

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %% [markdown]
# ## Relation between mainroad and price

# %%
d5=df.groupby('mainroad')['price'].mean().reset_index()
d5
# Out:
#   mainroad         price
# 0       no  3.398905e+06
# 1      yes  4.991777e+06

# %%
sns.set_style("whitegrid")
sns.set_palette("Set2")
sns.barplot(x='mainroad',y='price',data=d5)
# Out:
# <Axes: xlabel='mainroad', ylabel='price'>

# %% [markdown]
# * House price is more for houses which are connected to Main road

# %% [markdown]
# ## Relation between guestroom and price

# %%
d6=df.groupby('guestroom')['price'].mean().reset_index()
d6
# Out:
#   guestroom         price
# 0        no  4.544546e+06
# 1       yes  5.792897e+06

# %%
sns.barplot(x='guestroom',y='price',data=d6)
# Out:
# <Axes: xlabel='guestroom', ylabel='price'>

# %% [markdown]
# * Price is high for houses which has guestroom

# %% [markdown]
# ## Relation between basement and price

# %%
df.groupby('basement')['price'].mean().reset_index()
# Out:
#   basement         price
# 0       no  4.509966e+06
# 1      yes  5.242615e+06

# %%
sns.violinplot(x='basement',y='price',data=df)
# Out:
# <Axes: xlabel='basement', ylabel='price'>

# %% [markdown]
# * Average price of houses with Basement is high as compared to hosue that does not have basement

# %% [markdown]
# ## Relation between hotwaterheating and price

# %%
df.groupby('hotwaterheating')['price'].mean().reset_index()
# Out:
#   hotwaterheating         price
# 0              no  4.728593e+06
# 1             yes  5.559960e+06

# %%
sns.stripplot(x='hotwaterheating',y='price',data=df)
# Out:
# <Axes: xlabel='hotwaterheating', ylabel='price'>

# %% [markdown]
# * We can see there are more number of houses which do not ahve hot water heating facility
# * Price of house is higher for those do not have hot water heating facility
# * Having hot water heating facility in house does not significantly affect the price of house

# %% [markdown]
# ## Relation between airconditioning and price

# %%
df.groupby('airconditioning')['price'].mean().reset_index()
# Out:
#   airconditioning         price
# 0              no  4.191940e+06
# 1             yes  6.013221e+06

# %%
sns.swarmplot(x='airconditioning',y='price',data=df)
# Out:
# <Axes: xlabel='airconditioning', ylabel='price'>

# %% [markdown]
# * There are more houses taht does not have air conditioning facility
# * Price is high when house has air conditioning facility

# %% [markdown]
# ## Relation between parking and price

# %%
df[['parking','price']].groupby('parking').mean().reset_index()
# Out:
#    parking         price
# 0        0  4.136017e+06
# 1        1  5.190389e+06
# 2        2  5.896328e+06
# 3        3  5.867167e+06

# %%
sns.barplot(x='parking',y='price',data=df)
# Out:
# <Axes: xlabel='parking', ylabel='price'>

# %% [markdown]
# * House price is higher when it has parking lot
# * But when number of parking lot increases to 3, average price is starts decreasing.

# %% [markdown]
# ## Relation between prefarea and price

# %%
df.groupby('prefarea')['price'].mean().reset_index()
# Out:
#   prefarea         price
# 0       no  4.425299e+06
# 1      yes  5.879046e+06

# %%
sns.stripplot(x='prefarea',y='price',data=df)
# Out:
# <Axes: xlabel='prefarea', ylabel='price'>

# %% [markdown]
# * Most of the house are not in Preferred area
# * Average price of house is high for those house not in Preferred area

# %% [markdown]
# ## Relation between furnishingstatus and price

# %%
df[['furnishingstatus','price']].groupby('furnishingstatus',as_index=False).mean().sort_values(by='price',ascending=False)
# Out:
#   furnishingstatus         price
# 0        furnished  5.495696e+06
# 1   semi-furnished  4.907524e+06
# 2      unfurnished  4.013831e+06

# %%
sns.barplot(x='furnishingstatus',y='price',data=df)
# Out:
# <Axes: xlabel='furnishingstatus', ylabel='price'>

# %% [markdown]
# * Price of furnished house is higher than semi-furnished and unfurnished houses

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Average price and average area based on furnishingstatus

# %%
df.groupby(['furnishingstatus'])[['area','price']].mean().reset_index()
# Out:
#   furnishingstatus         area         price
# 0        furnished  5688.100000  5.495696e+06
# 1   semi-furnished  5166.339207  4.907524e+06
# 2      unfurnished  4707.595506  4.013831e+06

# %%
sns.scatterplot(x='area',y='price',hue='furnishingstatus',data=df)
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %% [markdown]
# * Area of Furnished house is more as compared to semi-furnished and unfurnished
# * Price is highest for furnished house
# * Price is lowest for unfurnished house
# * Moderate price for semi-furnished house

# %% [markdown]
# ### Average area and price based on mainroad

# %%
df.groupby(['mainroad'])[['area','price']].mean().reset_index()
# Out:
#   mainroad         area         price
# 0       no  3606.441558  3.398905e+06
# 1      yes  5404.591880  4.991777e+06

# %%
sns.scatterplot(x='area',y='price',hue='mainroad',data=df)
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %% [markdown]
# * Houses connected to main road has larger area as compared to houses not connected to main road
# * Majority of houses are connected to main road
# * Average price of house connected to main road is higher than house not connected to main road

# %% [markdown]
# ## Average area and price based on guestroom

# %%
df.groupby('guestroom')[['area','price']].mean().reset_index()
# Out:
#   guestroom         area         price
# 0        no  5009.000000  4.544546e+06
# 1       yes  5804.257732  5.792897e+06

# %%
sns.scatterplot(x='area',y='price',hue='guestroom',data=df)
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %% [markdown]
# * Majority of house has a guestroom
# * Area and price of house having guestroom is higher than house that does not has a guestroom

# %% [markdown]
# ## Average area and price based on basement

# %%
df.groupby('basement')[['area','price']].mean().reset_index()
# Out:
#   basement         area         price
# 0       no  5075.025424  4.509966e+06
# 1      yes  5290.502618  5.242615e+06

# %%
sns.scatterplot(x='area',y='price',hue='basement',data=df)
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %% [markdown]
# * Majority of house has a basement
# * Area and price of house that has basement is higher than houses that does not ahve a basement

# %%
cat_col=['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea', 'furnishingstatus']

# %% [markdown]
# ## Average area and price hotwaterheating

# %%
h=df.groupby('hotwaterheating')[['area','price']].mean().reset_index()
h
# Out:
#   hotwaterheating         area         price
# 0              no  5154.928846  4.728593e+06
# 1             yes  5059.280000  5.559960e+06

# %%
sns.barplot(x='area',y='price',hue='hotwaterheating',data=h)
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %% [markdown]
# * Price of house having hot water heating facility is high
# * Area of house that does not have hot wtaer heating facility is high

# %% [markdown]
# ## Average area and price airconditioning

# %%
a=df.groupby('airconditioning')[['area','price']].mean().reset_index()
a
# Out:
#   airconditioning         area         price
# 0              no  4823.109920  4.191940e+06
# 1             yes  5860.610465  6.013221e+06

# %%
sns.barplot(x='area',y='price',hue='airconditioning',data=a)
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %% [markdown]
# * Area and price of house having airconditioning facility is higher as compared to house not having airconditioning facility

# %% [markdown]
# ## Average area and price based on prefarea

# %%
df.groupby('prefarea')[['area','price']].mean().reset_index()
# Out:
#   prefarea         area         price
# 0       no  4868.517986  4.425299e+06
# 1      yes  6069.320312  5.879046e+06

# %%
sns.scatterplot(x='area',y='price',hue='prefarea',data=df)
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %% [markdown]
# * House that are in Preferred area has high price and larger area.

# %% [markdown]
# ## Relation between furnishing status, airconditioning and bedrooms

# %%
df.groupby('furnishingstatus')[['airconditioning','bedrooms']].value_counts(normalize=True)*100
# Out:
# furnishingstatus  airconditioning  bedrooms
# furnished         no               3           28.571429
#                   yes              3           25.714286
#                   no               2           17.142857
#                   yes              4           12.857143
#                   no               4            7.857143
#                   yes              2            3.571429
#                                    5            2.142857
#                   no               6            0.714286
#                                    5            0.714286
#                                    1            0.714286
# semi-furnished    no               3           37.885463
#                                    2           18.502203
#                   yes              3           18.061674
#                   no               4           14.096916
#                   yes              4            7.048458
#                                    2            3.524229
# ...

# %% [markdown]
# ## Barplot depicting relation between airconditioning,bedrooms and furnishingstatus

# %%
sns.barplot(x=df['airconditioning'],y=df['bedrooms'],hue=df["furnishingstatus"])
# Out:
# <Axes: xlabel='airconditioning', ylabel='bedrooms'>

# %% [markdown]
# * Most of houses has airconditioning facility
# * House that has airconditional facility, also has larger number of bedrooms

# %% [markdown]
# ## Barplot depicting relation between hotwaterheating, bathrooms and furnishingstatus features

# %%
df[['hotwaterheating','bathrooms','furnishingstatus']].groupby('furnishingstatus').value_counts(normalize=True)*100
# Out:
# furnishingstatus  hotwaterheating  bathrooms
# furnished         no               1            62.142857
#                                    2            32.142857
#                   yes              2             2.142857
#                                    1             2.142857
#                   no               4             0.714286
#                                    3             0.714286
# semi-furnished    no               1            67.841410
#                                    2            23.788546
#                   yes              1             4.405286
#                   no               3             2.202643
#                   yes              2             1.321586
#                                    3             0.440529
# unfurnished       no               1            81.460674
#                                    2            14.044944
#                                    3             1.685393
# ...

# %%
sns.barplot(x=df['hotwaterheating'],y=df['bathrooms'],hue=df["furnishingstatus"])
# Out:
# <Axes: xlabel='hotwaterheating', ylabel='bathrooms'>

# %% [markdown]
# * House that ahs hot water heating facility has more bathrooms compared to house not having hot water heating facility
# * Most of the houses do not ahve hot water heating facility
